# %%
#1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

#Ans

#To calculate the Pearson correlation coefficient between two variables, we need to first calculate the covariance between the two variables, as well as their individual standard deviations. Then, we can use the formula:

#r = cov(X,Y) / (s_X * s_Y)

#where r is the Pearson correlation coefficient, cov(X,Y) is the covariance between X and Y, s_X is the standard deviation of X, and s_Y is the standard deviation of Y.

#Assuming you have collected data on the amount of time students spend studying for an exam (X) and their final exam scores (Y), we can use the following steps to calculate the Pearson correlation coefficient:

#1 - Calculate the mean of X and Y.

#2 - Calculate the deviations from the mean for X and Y.

#3 - Calculate the squared deviations for X and Y.

#4 - Calculate the covariance between X and Y.

#5 - Calculate the standard deviation of X and Y.

#6 - Calculate the Pearson correlation coefficient using the formula above.

#Interpreting the result:

#The Pearson correlation coefficient is a number between -1 and 1 that indicates the strength and direction of the linear relationship between the two variables.

#If the Pearson correlation coefficient is close to 1, this indicates a strong positive linear relationship between the two variables, meaning that as one variable increases, the other variable also tends to increase.

#If the Pearson correlation coefficient is close to -1, this indicates a strong negative linear relationship between the two variables, meaning that as one variable increases, the other variable tends to decrease.

#If the Pearson correlation coefficient is close to 0, this indicates little or no linear relationship between the two variables.

# %%
#2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

#Ans

#To calculate the Spearman's rank correlation coefficient between two variables, we need to first assign a rank to each data point in both variables. Then, we can calculate the differences between the ranks for each data point in the two variables. Finally, we can use the formula:

#r_s = 1 - (6 * ∑d^2) / (n(n^2 - 1))

#where r_s is the Spearman's rank correlation coefficient, d is the difference between the ranks for each data point in the two variables, and n is the number of data points.

#Assuming we have collected data on the amount of sleep individuals get each night (X) and their overall job satisfaction level on a scale of 1 to 10 (Y), we can use the following steps to calculate the Spearman's rank correlation coefficient:

#1 - Rank the data for each variable separately.

#2 - Calculate the differences between the ranks for each data point in the two variables.

#3 - Square the differences and sum them.

#4 - Use the formula above to calculate the Spearman's rank correlation coefficient.

#Interpreting the result:

#The Spearman's rank correlation coefficient is a number between -1 and 1 that indicates the strength and direction of the monotonic relationship between the two variables.

#If the Spearman's rank correlation coefficient is close to 1, this indicates a strong monotonic positive relationship between the two variables, meaning that as one variable increases, the other variable tends to increase.

#If the Spearman's rank correlation coefficient is close to -1, this indicates a strong monotonic negative relationship between the two variables, meaning that as one variable increases, the other variable tends to decrease.

#If the Spearman's rank correlation coefficient is close to 0, this indicates little or no monotonic relationship between the two variables.

# %%
#3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

#Ans

#To calculate the Pearson correlation coefficient and the Spearman's rank correlation coefficient between the number of hours of exercise per week and body mass index (BMI) in a sample of 50 adults, we can follow the steps below:

#1 - Collect the data on both variables for 50 participants.

#2 - Calculate the mean and standard deviation for both variables.

#3 - Calculate the Pearson correlation coefficient using the formula:

#r = [∑(Xi - X)(Yi - Y)] / [(n-1)sXsY]

#where X and Y are the two variables, Xi and Yi are the values of the variables for each participant, sX and sY are the standard deviations of the two variables, and n is the sample size.

#4 - Calculate the Spearman's rank correlation coefficient using the formula:

#rs = 1 - [(6∑d^2)/(n(n^2 - 1))]

#where d is the difference between the ranks for each data point in the two variables, and n is the sample size.

#5 - Compare the results of the two coefficients.

#Interpreting the results:

#The Pearson correlation coefficient measures the strength and direction of the linear relationship between the two variables. It ranges from -1 to 1, where -1 indicates a perfect negative linear relationship, 0 indicates no linear relationship, and 1 indicates a perfect positive linear relationship.

#The Spearman's rank correlation coefficient measures the strength and direction of the monotonic relationship between the two variables. It ranges from -1 to 1, where -1 indicates a perfect negative monotonic relationship, 0 indicates no monotonic relationship, and 1 indicates a perfect positive monotonic relationship.

#If the relationship between the two variables is linear, the Pearson correlation coefficient will be a better measure of the relationship. If the relationship is monotonic but not linear, the Spearman's rank correlation coefficient will be a better measure of the relationship.

#If the relationship between the number of hours of exercise per week and BMI in the sample of 50 adults is linear, then the Pearson correlation coefficient will be a better measure of the relationship. If the relationship is not linear but monotonic, then the Spearman's rank correlation coefficient will be a better measure of the relationship.

#Comparing the results of the two coefficients, if the Pearson correlation coefficient is close to 1 or -1, and the Spearman's rank correlation coefficient is close to 1 or -1 as well, then it can be concluded that the relationship between the two variables is both linear and monotonic. If the Pearson correlation coefficient is close to 0, but the Spearman's rank correlation coefficient is not close to 0, then it can be concluded that the relationship is monotonic but not linear. If both coefficients are close to 0, then it can be concluded that there is no relationship between the two variables.

# %%
#4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.

#Ans

#To calculate the Pearson correlation coefficient between the number of hours individuals spend watching television per day and their level of physical activity in a sample of 50 participants, we can follow the steps below:

#1 - Collect the data on both variables for 50 participants.

#2 - Calculate the mean and standard deviation for both variables.

#3 - Calculate the Pearson correlation coefficient using the formula:

#r = [∑(Xi - X)(Yi - Y)] / [(n-1)sXsY]

#where X and Y are the two variables, Xi and Yi are the values of the variables for each participant, sX and sY are the standard deviations of the two variables, and n is the sample size.

#Interpreting the results:

#The Pearson correlation coefficient measures the strength and direction of the linear relationship between the two variables. It ranges from -1 to 1, where -1 indicates a perfect negative linear relationship, 0 indicates no linear relationship, and 1 indicates a perfect positive linear relationship.

#If the correlation coefficient is positive, it means that as the number of hours individuals spend watching television per day increases, their level of physical activity also tends to increase (positive relationship). If the correlation coefficient is negative, it means that as the number of hours individuals spend watching television per day increases, their level of physical activity tends to decrease (negative relationship). If the correlation coefficient is close to 0, it means that there is no linear relationship between the two variables.

# %%
#5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:

# ______________________________________
#|  Age(Years) | Soft drink Preference  |  
#|_____________|________________________|   
#|   25        |         Coke           |
#|   42        |         Pepsi          |
#|   37        |     Mountain dew       |
#|   19        |         Coke           |
#|   31        |         Pepsi          |
#|   28        |         Coke           |

#Ans

#To examine the relationship between age and preference for a particular brand of soft drink based on the survey results provided, you can use a contingency table to organize the data:

#| Age(Years) | Coke | Pepsi | Mountain Dew |
#|   18-25    |  2   |   0   |      0       |
#|   26-35    |  1   |   1   |      0       |
#|   36-45    |  0   |   1   |      1       |

#Interpreting the results:

#The contingency table shows the frequency distribution of the data, where each cell represents the number of participants who belong to a particular age group and prefer a particular brand of soft drink.

#To examine the relationship between age and soft drink preference, you can perform a chi-square test of independence. This statistical test can determine whether there is a significant association between two categorical variables.

#If the test results in a p-value less than 0.05, you can reject the null hypothesis that there is no association between age and soft drink preference and conclude that there is a significant relationship between the two variables. If the p-value is greater than 0.05, you fail to reject the null hypothesis, indicating that there is no significant relationship between the two variables.

# %%
#6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

#Ans

#To calculate the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week, we need to use the following formula:

#r = [n(Σxy) - (Σx)(Σy)] / sqrt{ [nΣx^2 - (Σx)^2][nΣy^2 - (Σy)^2] }

#where:

#n is the sample size
#Σxy is the sum of the products of each pair of corresponding x and y values
#Σx is the sum of all x values
#Σy is the sum of all y values
#Σx^2 is the sum of the squared values of x
#Σy^2 is the sum of the squared values of y
#Using the data provided, we can calculate the following values:

#n = 30
#Σx = 810
#Σy = 84
#Σx^2 = 24390
#Σy^2 = 570

#To calculate Σxy, we need to multiply each x value by its corresponding y value and sum the products:

#Σxy = (283) + (253) + (272) + (243) + (292) + (272) + (302) + (234) + (272) + (291) + (262) + (272) + (261) + (244) + (273) + (282) + (242) + (271) + (271) + (252) + (263) + (233) + (262) + (272) + (281) + (271) + (272) + (233) + (291) + (242) + (26*2) = 798

#Substituting these values into the formula, we get:

#r = [30(798) - (810)(84)] / sqrt{ [30(24390) - (810)^2][30(570) - (84)^2] }
#= 0.722

#Therefore, the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week is 0.722. This suggests a moderately strong positive relationship between the two variables.
